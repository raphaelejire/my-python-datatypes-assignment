# %% [markdown]
# ### Data types

# %%
#Numbers              RAPHAEL EJIRE ABEE 23/2069 IT GROUP C

# %% [markdown]
# ### Integer

# %%
t = 13
print(t)
# Out:
# 13

# %% [markdown]
# ### Float Numbers

# %%
Score = 98.9
print (Score)
# Out:
# 98.9

# %% [markdown]
# ### Complex numbers

# %%
S = 28 + 45j
print(S)
# Out:
# (28+45j)

# %% [markdown]
# ### String

# %%
StudentName = "Ejire Raphael"
print (StudentName)
# Out:
# Ejire Raphael

# %% [markdown]
# ### Boolean

# %%
question = "Are you okay?"
yes = True
no = False
print(question)
print(yes)
# Out:
# Are you okay?
# True

# %% [markdown]
# ### Data Structures

# %%
#Lists, sets, tuples and dictionary

# %%
age = [26, 45, 78, 66, 89, 87]
print(age)
# Out:
# [26, 45, 78, 66, 89, 87]

# %%
age = { 33, 76, 21, 77, 54, 77}
print(age)
# Out:
# {33, 21, 54, 76, 77}

# %%
number = (34, 66, 21, 55, 12, 45)
print(number)
# Out:
# (34, 66, 21, 55, 12, 45)

# %%
studentInfo = {
    "name": "Raphael",
    "age ": 19,
    "is_studentInfo": True
}

print(studentInfo.values())
# Out:
# dict_values(['Raphael', 19, True])
